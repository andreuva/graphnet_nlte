# %%
from lightweaver.fal import Falc82
from lightweaver.rh_atoms import H_6_atom, H_6_CRD_atom, H_3_atom, C_atom, O_atom, OI_ord_atom, \
                                 Si_atom, Al_atom, CaII_atom, Fe_atom, FeI_atom, He_9_atom, \
                                 He_atom, He_large_atom, MgII_atom, N_atom, Na_atom, S_atom
import lightweaver as lw
import matplotlib.pyplot as plt
import numpy as np
import astropy

from astropy.io import fits

# %%
nx, ny, nz = 504, 504, 425
nlev = 6
datadir = '../data_porta'
datadir_original = '../en024048_hion/muram_adapt/'
grid_dir = '../en024048_hion/'

# %%
pops = np.memmap(f'{datadir}/AR_385_CaII_5L_pops.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, nlev))
b_xyz = np.memmap(f'{datadir}/AR_385_B.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 3))
temp = np.memmap(f'{datadir}/AR_385_temp.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 1))
v_xyz = np.memmap(f'{datadir}/AR_385_veloc.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 3))
ne = np.memmap(f'{datadir}/AR_385_ne.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 1))
rho = np.memmap(f'{datadir}/AR_385_mass.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 1))
press = np.memmap(f'{datadir}/AR_385_press.dat', dtype='<f4', mode='r', shape=(nz, ny, nx, 1))

# %%
geometry_file = f'{grid_dir}grid_bifrost.npz'
geometry_grid = np.load(geometry_file)["z"]

# %%
nwave = 1001
wave = np.linspace(853.9444, 854.9444, nwave)
I_lte, I_nlte, I_target = np.zeros((nwave)), np.zeros((nwave)), np.zeros((nwave))

col_pix = 234
row_pix = 234

# %%
def synth_8542(atmos, conserve, useNe, wave):
    '''
    Synthesise a spectral line for given atmosphere with different
    conditions.

    Parameters
    ----------
    atmos : lw.Atmosphere
        The atmospheric model in which to synthesise the line.
    conserve : bool
        Whether to start from LTE electron density and conserve charge, or
        simply use from the electron density present in the atomic model.
    useNe : bool
        Whether to use the electron density present in the model as the
        starting solution, or compute the LTE electron density.
    wave : np.ndarray
        Array of wavelengths over which to resynthesise the final line
        profile for muz=1.

    Returns
    -------
    ctx : lw.Context
        The Context object that was used to compute the equilibrium
        populations.
    Iwave : np.ndarray
        The intensity at muz=1 for each wavelength in `wave`.
    '''
    # Configure the atmospheric angular quadrature
    atmos.quadrature(5)
    # Configure the set of atomic models to use.
    aSet = lw.RadiativeSet([H_6_atom(), C_atom(), O_atom(), Si_atom(),
                            Al_atom(), CaII_atom(), Fe_atom(), He_9_atom(),
                            MgII_atom(), N_atom(), Na_atom(), S_atom()
                           ])
    # Set H and Ca to "active" i.e. NLTE, everything else participates as an
    # LTE background.
    aSet.set_active('H', 'Ca')
    # Compute the necessary wavelength dependent information (SpectrumConfiguration).
    spect = aSet.compute_wavelength_grid()

    # Either compute the equilibrium populations at the fixed electron density
    # provided in the model, or iterate an LTE electron density and compute the
    # corresponding equilibrium populations (SpeciesStateTable).
    if useNe:
        eqPops = aSet.compute_eq_pops(atmos)
    else:
        eqPops = aSet.iterate_lte_ne_eq_pops(atmos)

    # Configure the Context which holds the state of the simulation for the
    # backend, and provides the python interface to the backend.
    # Feel free to increase Nthreads to increase the number of threads the
    # program will use.
    ctx = lw.Context(atmos, spect, eqPops, conserveCharge=conserve, Nthreads=1)
    # Iterate the Context to convergence (using the iteration function now
    # provided by Lightweaver)
    lw.iterate_ctx_se(ctx)
    # Update the background populations based on the converged solution and
    # compute the final intensity for mu=1 on the provided wavelength grid.
    eqPops.update_lte_atoms_Hmin_pops(atmos)
    Iwave = ctx.compute_rays(wave, [atmos.muz[-1]], stokes=False)
    return ctx, eqPops, Iwave

# %%
# Falc82 atmosphere NLTE Calculations
atmosRef = Falc82()
ctx_lw_nlte, eqPops_lw_nlte, I_lw_nlte = synth_8542(atmosRef, conserve=False, useNe=True, wave=wave)
# Out:
# -- Iteration 0:
# dJ = 1.00e+00
#     (Lambda iterating background)
# -- Iteration 9:
# dJ = 1.00e+00
#     H delta = 2.9038e-01
#     Ca delta = 2.3130e-01
# -- Iteration 18:
# dJ = 1.41e-01
#     H delta = 7.3603e-02
#     Ca delta = 6.8821e-02
# -- Iteration 27:
# dJ = 8.50e-02
#     H delta = 5.0410e-02
#     Ca delta = 3.4541e-02
# -- Iteration 36:
# dJ = 7.28e-02
#     H delta = 4.3635e-02
#     Ca delta = 2.3167e-02
# -- Iteration 45:
# dJ = 6.32e-02
#     H delta = 3.4624e-02
#     Ca delta = 1.5864e-02
# -- Iteration 54:
# dJ = 5.04e-02
#     H delta = 2.5356e-02
#     Ca delta = 9.7035e-03
# -- Iteration 63:
# dJ = 3.31e-02
#     H delta = 1.8010e-02
#     Ca delta = 5.1067e-03
# -- Iteration 72:
# dJ = 1.79e-02
#     H delta = 1.0098e-02
#     Ca delta = 2.3932e-03
# -- Iteration 81:
# dJ = 8.30e-03
#     H delta = 4.7805e-03
#     Ca delta = 1.0351e-03
# -- Iteration 90:
# dJ = 3.56e-03
#     H delta = 2.0733e-03
#     Ca delta = 4.3477e-04
# --------------------------------------------------------------------------------
# Final Iteration: 98
# --------------------------------------------------------------------------------
# dJ = 1.61e-03
#     H delta = 9.3709e-04
#     Ca delta = 1.9178e-04
# --------------------------------------------------------------------------------
# Context converged to statistical equilibrium in 98 iterations after 2.40 s.
# --------------------------------------------------------------------------------
# LTE Iterations 1 (-- slowest convergence)

# %%
# Note: We slice at [row_pix] fixed, iterating [col_pix]
temp_atm = np.ascontiguousarray(temp[:, col_pix, row_pix, 0].astype(np.float64))
b_xyz_atm = np.ascontiguousarray(b_xyz[:, col_pix, row_pix, 2].astype(np.float64))
vel_atm = np.ascontiguousarray(v_xyz[:, col_pix, row_pix, 2].astype(np.float64))/1e2
n_e_atm = np.ascontiguousarray(ne[:, col_pix, row_pix, 0].astype(np.float64))*1e6
press = np.ascontiguousarray(press[:, col_pix, row_pix, 0].astype(np.float64))*1e6
pops_atm = np.ascontiguousarray(pops[:, col_pix, row_pix, :].astype(np.float64))*1e6
z_atm = np.ascontiguousarray(geometry_grid[:].astype(np.float64))*1e6
# set z_atm to astropy units in m
z_atm = astropy.units.Quantity(z_atm, astropy.units.m)

useful_atm_slice = slice(None, None, -1)

temp_atm = np.ascontiguousarray(temp_atm[useful_atm_slice].astype(np.float64))
b_xyz_atm = np.ascontiguousarray(b_xyz_atm[useful_atm_slice].astype(np.float64))
vel_atm = np.ascontiguousarray(vel_atm[useful_atm_slice].astype(np.float64))
n_e_atm = np.ascontiguousarray(n_e_atm[useful_atm_slice].astype(np.float64))
press = np.ascontiguousarray(press[useful_atm_slice].astype(np.float64))
pops_atm = np.ascontiguousarray(pops_atm[useful_atm_slice].astype(np.float64))
z_atm = np.ascontiguousarray(z_atm[useful_atm_slice].astype(np.float64))

useful_atm_slice = slice(None, None, 1)

# --- Plotting atmosphere parameters ---
# Assuming Lightweaver standard units (CGS)
z_falc_m = atmosRef.z               # m
temp_falc = atmosRef.temperature    # K
vlos_falc = atmosRef.vlos           # cm/s (typically 0 for FALC)
nh_falc = atmosRef.nHTot            # cm^-3
ne_falc = atmosRef.ne               # cm^-3

# %%
plt.figure(figsize=(20, 2))
plt.plot(z_atm[useful_atm_slice]/1e6, z_atm[useful_atm_slice] * 0, '|', markersize=20, label='z_atm useful_slice')
plt.plot(geometry_grid, geometry_grid * 0, '|', label='geometry file grid')
plt.plot(atmosRef.z/1e6, atmosRef.z * 0, '|', label='FAL-C grid')
plt.xlabel('Height (Mm)')
plt.legend()
plt.title('Comparison of Original and Interpolated Geometry Grids')
plt.show()
# plt.close()

# %%
atmos_lte = lw.Atmosphere.make_1d(scale=lw.ScaleType.Geometric, 
                                depthScale=z_atm[useful_atm_slice], 
                                temperature=temp_atm[useful_atm_slice],
                                vturb=0e4*np.ones_like(temp_atm[useful_atm_slice]),
                                vlos=vel_atm[useful_atm_slice])
ctx_lte, eqPops_lte, I_lte = synth_8542(atmos_lte, conserve=False, useNe=False, wave=wave)
# Out:
# -- Iteration 0:
# dJ = 1.00e+00
#     (Lambda iterating background)
# -- Iteration 2:
# dJ = 1.97e-01
#     (Lambda iterating background)
# -- Iteration 4:
# dJ = 2.48e+01
#     H delta = 7.6687e-01
#     Ca delta = 1.6358e+00
# -- Iteration 6:
# dJ = 6.36e-01
#     H delta = 4.2147e-01
#     Ca delta = 1.7836e-01
# -- Iteration 8:
# dJ = 7.10e-01
#     H delta = 2.3788e-01
#     Ca delta = 1.1245e-01
# -- Iteration 10:
# dJ = 5.28e-01
#     H delta = 1.5709e-01
#     Ca delta = 8.6492e-02
# -- Iteration 12:
# dJ = 3.44e-01
#     H delta = 1.2059e-01
#     Ca delta = 7.6717e-02
# -- Iteration 14:
# dJ = 3.13e-01
#     H delta = 9.9888e-02
#     Ca delta = 6.8552e-02
# -- Iteration 16:
# dJ = 3.12e-01
#     H delta = 9.3856e-02
#     Ca delta = 6.2784e-02
# -- Iteration 18:
# dJ = 3.22e-01
#     H delta = 9.4040e-02
#     Ca delta = 5.8135e-02
# -- Iteration 20:
# dJ = 3.04e-01
#     H delta = 9.2706e-02
#     Ca delta = 5.4039e-02
# -- Iteration 22:
# dJ = 2.98e-01
#     H delta = 8.8871e-02
#     Ca delta = 5.0277e-02
# -- Iteration 24:
# dJ = 2.66e-01
#     H delta = 8.3657e-02
#     Ca delta = 4.6797e-02
# -- Iteration 26:
# dJ = 2.45e-01
#     H delta = 7.7968e-02
#     Ca delta = 4.3481e-02
# -- Iteration 28:
# dJ = 2.19e-01
#     H delta = 7.0643e-02
#     Ca delta = 4.1775e-02
# -- Iteration 30:
# dJ = 1.96e-01
#     H delta = 6.4058e-02
#     Ca delta = 4.0466e-02
# -- Iteration 32:
# dJ = 1.68e-01
#     H delta = 5.9551e-02
#     Ca delta = 3.9723e-02
# -- Iteration 34:
# dJ = 1.48e-01
#     H delta = 5.8043e-02
#     Ca delta = 3.8878e-02
# -- Iteration 36:
# dJ = 1.26e-01
#     H delta = 5.5854e-02
#     Ca delta = 3.7826e-02
# -- Iteration 38:
# dJ = 1.05e-01
#     H delta = 5.3087e-02
#     Ca delta = 3.6190e-02
# -- Iteration 40:
# dJ = 9.00e-02
#     H delta = 4.9542e-02
#     Ca delta = 3.3933e-02
# -- Iteration 42:
# dJ = 7.55e-02
#     H delta = 4.5227e-02
#     Ca delta = 3.0980e-02
# -- Iteration 44:
# dJ = 6.23e-02
#     H delta = 4.0402e-02
#     Ca delta = 2.7602e-02
# -- Iteration 46:
# dJ = 5.18e-02
#     H delta = 3.5079e-02
#     Ca delta = 2.3885e-02
# -- Iteration 48:
# dJ = 4.44e-02
#     H delta = 2.9762e-02
#     Ca delta = 2.0161e-02
# -- Iteration 50:
# dJ = 3.73e-02
#     H delta = 2.6237e-02
#     Ca delta = 1.6538e-02
# -- Iteration 52:
# dJ = 3.05e-02
#     H delta = 2.3802e-02
#     Ca delta = 1.3301e-02
# -- Iteration 54:
# dJ = 2.44e-02
#     H delta = 2.1293e-02
#     Ca delta = 1.0460e-02
# -- Iteration 56:
# dJ = 2.04e-02
#     H delta = 1.8787e-02
#     Ca delta = 8.0707e-03
# -- Iteration 58:
# dJ = 1.78e-02
#     H delta = 1.6356e-02
#     Ca delta = 6.1701e-03
# -- Iteration 60:
# dJ = 1.54e-02
#     H delta = 1.4062e-02
#     Ca delta = 4.6697e-03
# -- Iteration 62:
# dJ = 1.31e-02
#     H delta = 1.1952e-02
#     Ca delta = 3.5097e-03
# -- Iteration 64:
# dJ = 1.11e-02
#     H delta = 1.0054e-02
#     Ca delta = 2.6254e-03
# -- Iteration 66:
# dJ = 9.24e-03
#     H delta = 8.3782e-03
#     Ca delta = 1.9584e-03
# -- Iteration 68:
# dJ = 7.66e-03
#     H delta = 6.9246e-03
#     Ca delta = 1.4632e-03
# -- Iteration 70:
# dJ = 6.30e-03
#     H delta = 5.6823e-03
#     Ca delta = 1.0959e-03
# -- Iteration 72:
# dJ = 5.14e-03
#     H delta = 4.6342e-03
#     Ca delta = 8.2122e-04
# -- Iteration 74:
# dJ = 4.18e-03
#     H delta = 3.7592e-03
#     Ca delta = 6.1605e-04
# -- Iteration 76:
# dJ = 3.38e-03
#     H delta = 3.0350e-03
#     Ca delta = 4.6277e-04
# -- Iteration 78:
# dJ = 2.72e-03
#     H delta = 2.4403e-03
#     Ca delta = 3.5514e-04
# -- Iteration 80:
# dJ = 2.18e-03
#     H delta = 1.9551e-03
#     Ca delta = 2.7805e-04
# -- Iteration 82:
# dJ = 1.75e-03
#     H delta = 1.5610e-03
#     Ca delta = 2.1730e-04
# -- Iteration 84:
# dJ = 1.39e-03
#     H delta = 1.2427e-03
#     Ca delta = 1.6982e-04
# -- Iteration 86:
# dJ = 1.11e-03
#     H delta = 9.8683e-04
#     Ca delta = 1.3263e-04
# Final Iteration shown above.
# --------------------------------------------------------------------------------
# Context converged to statistical equilibrium in 86 iterations after 12.45 s.
# --------------------------------------------------------------------------------
# LTE Iterations 1 (He slowest convergence)

# %%
atmos_nlte = lw.Atmosphere.make_1d(scale=lw.ScaleType.Geometric, 
                                depthScale=z_atm[useful_atm_slice],
                                temperature=temp_atm[useful_atm_slice],
                                vturb=0e4*np.ones_like(temp_atm[useful_atm_slice]),
                                vlos=vel_atm[useful_atm_slice])
ctx_nlte, eqPops_nlte, I_nlte = synth_8542(atmos_nlte, conserve=True, useNe=True, wave=wave)
# Out:
# -- Iteration 0:
# dJ = 1.00e+00
#     (Lambda iterating background)
# -- Iteration 2:
# dJ = 1.96e-01
#     (Lambda iterating background)
# -- Iteration 4:
# dJ = 9.88e+01
#     H delta = 3.3709e+01
#     Ca delta = 2.9914e+01
#     ne delta = 4.5677e-01
# -- Iteration 6:
# dJ = 6.65e-01
#     H delta = 4.1400e-01
#     Ca delta = 2.5417e-01
#     ne delta = 3.2052e-01
# -- Iteration 8:
# dJ = 6.23e-01
#     H delta = 2.3194e-01
#     Ca delta = 8.9284e-02
#     ne delta = 1.1813e-02
# -- Iteration 10:
# dJ = 5.15e-01
#     H delta = 1.5474e-01
#     Ca delta = 7.9235e-02
#     ne delta = 1.0320e-13
# -- Iteration 12:
# dJ = 3.69e-01
#     H delta = 1.1862e-01
#     Ca delta = 7.0757e-02
#     ne delta = 6.3047e-15
# -- Iteration 14:
# dJ = 3.19e-01
#     H delta = 9.8297e-02
#     Ca delta = 6.4169e-02
#     ne delta = 1.2576e-14
# -- Iteration 16:
# dJ = 3.12e-01
#     H delta = 9.1490e-02
#     Ca delta = 5.9405e-02
#     ne delta = 6.0144e-15
# -- Iteration 18:
# dJ = 3.23e-01
#     H delta = 9.1004e-02
#     Ca delta = 5.5352e-02
#     ne delta = 5.3310e-15
# -- Iteration 20:
# dJ = 3.06e-01
#     H delta = 8.8525e-02
#     Ca delta = 5.1704e-02
#     ne delta = 1.0542e-15
# -- Iteration 22:
# dJ = 2.98e-01
#     H delta = 8.4931e-02
#     Ca delta = 4.8366e-02
#     ne delta = 7.4192e-16
# -- Iteration 24:
# dJ = 2.71e-01
#     H delta = 7.9486e-02
#     Ca delta = 4.5106e-02
#     ne delta = 1.9820e-14
# -- Iteration 26:
# dJ = 2.47e-01
#     H delta = 7.3482e-02
#     Ca delta = 4.3022e-02
#     ne delta = 6.4580e-16
# -- Iteration 28:
# dJ = 2.18e-01
#     H delta = 6.6851e-02
#     Ca delta = 4.1819e-02
#     ne delta = 1.3533e-14
# -- Iteration 30:
# dJ = 1.97e-01
#     H delta = 6.0028e-02
#     Ca delta = 4.0485e-02
#     ne delta = 2.4605e-15
# -- Iteration 32:
# dJ = 1.71e-01
#     H delta = 5.7963e-02
#     Ca delta = 3.8897e-02
#     ne delta = 6.8346e-15
# -- Iteration 34:
# dJ = 1.48e-01
#     H delta = 5.5604e-02
#     Ca delta = 3.7021e-02
#     ne delta = 1.5173e-14
# -- Iteration 36:
# dJ = 1.29e-01
#     H delta = 5.2740e-02
#     Ca delta = 3.4730e-02
#     ne delta = 1.6403e-15
# -- Iteration 38:
# dJ = 1.10e-01
#     H delta = 4.9145e-02
#     Ca delta = 3.2055e-02
#     ne delta = 3.0619e-14
# -- Iteration 40:
# dJ = 9.17e-02
#     H delta = 4.4877e-02
#     Ca delta = 2.8926e-02
#     ne delta = 1.4812e-15
# -- Iteration 42:
# dJ = 7.67e-02
#     H delta = 4.0115e-02
#     Ca delta = 2.5533e-02
#     ne delta = 9.5684e-16
# -- Iteration 44:
# dJ = 6.41e-02
#     H delta = 3.4965e-02
#     Ca delta = 2.1929e-02
#     ne delta = 2.5392e-15
# -- Iteration 46:
# dJ = 5.28e-02
#     H delta = 2.9775e-02
#     Ca delta = 1.8393e-02
#     ne delta = 2.0504e-15
# -- Iteration 48:
# dJ = 4.30e-02
#     H delta = 2.5027e-02
#     Ca delta = 1.5057e-02
#     ne delta = 4.4436e-15
# -- Iteration 50:
# dJ = 3.46e-02
#     H delta = 2.2623e-02
#     Ca delta = 1.2071e-02
#     ne delta = 1.4489e-14
# -- Iteration 52:
# dJ = 2.77e-02
#     H delta = 2.0178e-02
#     Ca delta = 9.4914e-03
#     ne delta = 8.2235e-16
# -- Iteration 54:
# dJ = 2.20e-02
#     H delta = 1.7757e-02
#     Ca delta = 7.3259e-03
#     ne delta = 4.7842e-15
# -- Iteration 56:
# dJ = 1.74e-02
#     H delta = 1.5424e-02
#     Ca delta = 5.5757e-03
#     ne delta = 3.5813e-14
# -- Iteration 58:
# dJ = 1.45e-02
#     H delta = 1.3234e-02
#     Ca delta = 4.2027e-03
#     ne delta = 8.4641e-16
# -- Iteration 60:
# dJ = 1.23e-02
#     H delta = 1.1228e-02
#     Ca delta = 3.1481e-03
#     ne delta = 5.7133e-15
# -- Iteration 62:
# dJ = 1.04e-02
#     H delta = 9.4288e-03
#     Ca delta = 2.3556e-03
#     ne delta = 1.2712e-14
# -- Iteration 64:
# dJ = 8.67e-03
#     H delta = 7.8409e-03
#     Ca delta = 1.7657e-03
#     ne delta = 8.4981e-15
# -- Iteration 66:
# dJ = 7.16e-03
#     H delta = 6.4641e-03
#     Ca delta = 1.3240e-03
#     ne delta = 2.0504e-14
# -- Iteration 68:
# dJ = 5.87e-03
#     H delta = 5.2885e-03
#     Ca delta = 1.0090e-03
#     ne delta = 1.6928e-15
# -- Iteration 70:
# dJ = 4.78e-03
#     H delta = 4.2975e-03
#     Ca delta = 7.7271e-04
#     ne delta = 3.1740e-15
# -- Iteration 72:
# dJ = 3.87e-03
#     H delta = 3.4712e-03
#     Ca delta = 2.0398e-03
#     ne delta = 1.3408e-14
# -- Iteration 74:
# dJ = 3.12e-03
#     H delta = 2.7887e-03
#     Ca delta = 1.2549e-03
#     ne delta = 1.6996e-15
# -- Iteration 76:
# dJ = 2.50e-03
#     H delta = 2.2296e-03
#     Ca delta = 5.9356e-04
#     ne delta = 6.6096e-15
# -- Iteration 78:
# dJ = 2.20e-03
#     H delta = 2.0229e-03
#     Ca delta = 7.6568e-04
#     ne delta = 7.9068e-16
# -- Iteration 80:
# dJ = 2.01e-03
#     H delta = 1.8532e-03
#     Ca delta = 1.1224e-03
#     ne delta = 2.9649e-14
# -- Iteration 82:
# dJ = 1.84e-03
#     H delta = 1.6965e-03
#     Ca delta = 5.1492e-04
#     ne delta = 6.6642e-16
# -- Iteration 84:
# dJ = 1.69e-03
#     H delta = 1.5519e-03
#     Ca delta = 1.0594e-03
#     ne delta = 1.7086e-14
# -- Iteration 86:
# dJ = 1.54e-03
#     H delta = 1.4188e-03
#     Ca delta = 1.2048e-03
#     ne delta = 1.0252e-14
# -- Iteration 88:
# dJ = 1.41e-03
#     H delta = 1.2963e-03
#     Ca delta = 5.6134e-04
#     ne delta = 7.6548e-15
# -- Iteration 90:
# dJ = 1.29e-03
#     H delta = 1.1838e-03
#     Ca delta = 8.5695e-04
#     ne delta = 1.4626e-14
# -- Iteration 92:
# dJ = 1.17e-03
#     H delta = 1.0805e-03
#     Ca delta = 1.2180e-03
#     ne delta = 6.0431e-15
# -- Iteration 94:
# dJ = 1.07e-03
#     H delta = 9.8577e-04
#     Ca delta = 1.2552e-03
#     ne delta = 2.9082e-14
# -- Iteration 96:
# dJ = 9.78e-04
#     H delta = 8.9900e-04
#     Ca delta = 1.6105e-03
#     ne delta = 2.3276e-15
# --------------------------------------------------------------------------------
# Final Iteration: 97
# --------------------------------------------------------------------------------
# dJ = 9.33e-04
#     H delta = 8.5840e-04
#     Ca delta = 9.3200e-04
#     ne delta = 5.6654e-14
# --------------------------------------------------------------------------------
# Context converged to statistical equilibrium in 97 iterations after 13.52 s.
# --------------------------------------------------------------------------------
# LTE Iterations 1 (-- slowest convergence)

# %%
atmos_target = lw.Atmosphere.make_1d(scale=lw.ScaleType.Geometric, 
                                    depthScale=z_atm[useful_atm_slice], 
                                    temperature=temp_atm[useful_atm_slice],
                                    vturb=0e4*np.ones_like(temp_atm[useful_atm_slice]),
                                    vlos=vel_atm[useful_atm_slice])

ctx_target, eqPops_target, I_target = synth_8542(atmos_target, conserve=False, useNe=True, wave=wave)
eqPops_target.atomicPops['Ca'].n = np.ascontiguousarray(np.moveaxis(pops_atm[useful_atm_slice, :], 1, 0))
I_target = ctx_target.compute_rays(wave, [atmos_target.muz[-1]], stokes=False)
# Out:
# -- Iteration 0:
# dJ = 1.00e+00
#     (Lambda iterating background)
# -- Iteration 2:
# dJ = 1.96e-01
#     (Lambda iterating background)
# -- Iteration 4:
# dJ = 2.75e+01
#     H delta = 7.1194e-01
#     Ca delta = 1.7571e+00
# -- Iteration 6:
# dJ = 6.39e-01
#     H delta = 4.2529e-01
#     Ca delta = 1.8232e-01
# -- Iteration 8:
# dJ = 6.98e-01
#     H delta = 2.4423e-01
#     Ca delta = 1.2192e-01
# -- Iteration 10:
# dJ = 5.90e-01
#     H delta = 1.6098e-01
#     Ca delta = 9.8182e-02
# -- Iteration 12:
# dJ = 4.08e-01
#     H delta = 1.2203e-01
#     Ca delta = 8.3213e-02
# -- Iteration 14:
# dJ = 3.26e-01
#     H delta = 1.0142e-01
#     Ca delta = 7.3879e-02
# -- Iteration 16:
# dJ = 3.17e-01
#     H delta = 9.6890e-02
#     Ca delta = 6.6885e-02
# -- Iteration 18:
# dJ = 3.32e-01
#     H delta = 9.6835e-02
#     Ca delta = 6.1293e-02
# -- Iteration 20:
# dJ = 3.18e-01
#     H delta = 9.5043e-02
#     Ca delta = 5.6562e-02
# -- Iteration 22:
# dJ = 3.10e-01
#     H delta = 9.1317e-02
#     Ca delta = 5.2254e-02
# -- Iteration 24:
# dJ = 2.82e-01
#     H delta = 8.6684e-02
#     Ca delta = 4.8556e-02
# -- Iteration 26:
# dJ = 2.59e-01
#     H delta = 8.1174e-02
#     Ca delta = 4.4985e-02
# -- Iteration 28:
# dJ = 2.33e-01
#     H delta = 7.4246e-02
#     Ca delta = 4.2491e-02
# -- Iteration 30:
# dJ = 2.10e-01
#     H delta = 6.7751e-02
#     Ca delta = 4.1187e-02
# -- Iteration 32:
# dJ = 1.82e-01
#     H delta = 6.0749e-02
#     Ca delta = 3.9907e-02
# -- Iteration 34:
# dJ = 1.61e-01
#     H delta = 5.9088e-02
#     Ca delta = 3.9357e-02
# -- Iteration 36:
# dJ = 1.38e-01
#     H delta = 5.7429e-02
#     Ca delta = 3.8389e-02
# -- Iteration 38:
# dJ = 1.18e-01
#     H delta = 5.5266e-02
#     Ca delta = 3.7177e-02
# -- Iteration 40:
# dJ = 1.01e-01
#     H delta = 5.2304e-02
#     Ca delta = 3.5365e-02
# -- Iteration 42:
# dJ = 8.55e-02
#     H delta = 4.8671e-02
#     Ca delta = 3.2824e-02
# -- Iteration 44:
# dJ = 7.09e-02
#     H delta = 4.4323e-02
#     Ca delta = 2.9787e-02
# -- Iteration 46:
# dJ = 5.85e-02
#     H delta = 3.9332e-02
#     Ca delta = 2.6255e-02
# -- Iteration 48:
# dJ = 5.14e-02
#     H delta = 3.4054e-02
#     Ca delta = 2.2572e-02
# -- Iteration 50:
# dJ = 4.40e-02
#     H delta = 2.9591e-02
#     Ca delta = 1.8836e-02
# -- Iteration 52:
# dJ = 3.67e-02
#     H delta = 2.7217e-02
#     Ca delta = 1.5351e-02
# -- Iteration 54:
# dJ = 2.99e-02
#     H delta = 2.4690e-02
#     Ca delta = 1.2233e-02
# -- Iteration 56:
# dJ = 2.40e-02
#     H delta = 2.2087e-02
#     Ca delta = 9.5412e-03
# -- Iteration 58:
# dJ = 2.11e-02
#     H delta = 1.9485e-02
#     Ca delta = 7.3380e-03
# -- Iteration 60:
# dJ = 1.84e-02
#     H delta = 1.6961e-02
#     Ca delta = 5.5664e-03
# -- Iteration 62:
# dJ = 1.59e-02
#     H delta = 1.4580e-02
#     Ca delta = 4.1812e-03
# -- Iteration 64:
# dJ = 1.36e-02
#     H delta = 1.2391e-02
#     Ca delta = 3.1191e-03
# -- Iteration 66:
# dJ = 1.14e-02
#     H delta = 1.0422e-02
#     Ca delta = 2.3180e-03
# -- Iteration 68:
# dJ = 9.57e-03
#     H delta = 8.6838e-03
#     Ca delta = 1.7270e-03
# -- Iteration 70:
# dJ = 7.92e-03
#     H delta = 7.1739e-03
#     Ca delta = 1.2846e-03
# -- Iteration 72:
# dJ = 6.51e-03
#     H delta = 5.8831e-03
#     Ca delta = 9.5483e-04
# -- Iteration 74:
# dJ = 5.32e-03
#     H delta = 4.7938e-03
#     Ca delta = 7.0963e-04
# -- Iteration 76:
# dJ = 4.32e-03
#     H delta = 3.8847e-03
#     Ca delta = 5.5451e-04
# -- Iteration 78:
# dJ = 3.49e-03
#     H delta = 3.1329e-03
#     Ca delta = 4.3363e-04
# -- Iteration 80:
# dJ = 2.80e-03
#     H delta = 2.5161e-03
#     Ca delta = 3.3862e-04
# -- Iteration 82:
# dJ = 2.25e-03
#     H delta = 2.0134e-03
#     Ca delta = 2.6405e-04
# -- Iteration 84:
# dJ = 1.79e-03
#     H delta = 1.6060e-03
#     Ca delta = 2.0561e-04
# -- Iteration 86:
# dJ = 1.43e-03
#     H delta = 1.2775e-03
#     Ca delta = 1.5986e-04
# -- Iteration 88:
# dJ = 1.13e-03
#     H delta = 1.0136e-03
#     Ca delta = 1.2409e-04
# --------------------------------------------------------------------------------
# Final Iteration: 89
# --------------------------------------------------------------------------------
# dJ = 1.01e-03
#     H delta = 9.0211e-04
#     Ca delta = 1.0925e-04
# --------------------------------------------------------------------------------
# Context converged to statistical equilibrium in 89 iterations after 11.87 s.
# --------------------------------------------------------------------------------
# LTE Iterations 1 (-- slowest convergence)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 7), sharey=True, sharex=True)
# Define colors for different levels
colors = plt.cm.jet(np.linspace(0, 0.9, nlev))
# --- Subplot 1: FALC82 Atmosphere (atmosRef) ---
ax1 = axes[0]

levels = [5] # np.arange(nlev)
for i in levels:
    # Plot NLTE populations for FALC
    ax1.plot(z_falc_m, np.log10(eqPops_lw_nlte.atomicPops['Ca'].n[i, :]), 
             color=colors[i], linestyle='-', linewidth=2, label=f'Level {i}')

ax1.set_title("FALC82 Atmosphere (Reference)")
ax1.set_xlabel("Height [m]")
ax1.set_ylabel(r"$\log_{10}$ Population Density [cm$^{-3}$]")
ax1.grid(True, alpha=0.3)
ax1.legend(loc='lower left', ncol=2, fontsize='small', title='Atomic Levels')

# --- Subplot 2: Bifrost Pixel Atmospheres ---
ax2 = axes[1]

for i in levels:
    # LTE Populations (Dashed)
    ax2.plot(z_atm[useful_atm_slice], np.log10(eqPops_lte.atomicPops['Ca'].n[i, :]), 
             color=colors[i], linestyle='--', alpha=0.6)
    
    # Target Populations (Solid)
    ax2.plot(z_atm[useful_atm_slice], np.log10(pops_atm[useful_atm_slice, i]), 
             color=colors[i], linestyle='-', linewidth=2)
    
    # NLTE Populations (Dotted)
    ax2.plot(z_atm[useful_atm_slice], np.log10(eqPops_nlte.atomicPops['Ca'].n[i, :]), 
             color=colors[i], linestyle=':', linewidth=2.5)

# Create legend for calculation modes in the second plot
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='k', lw=2, linestyle='-'),
                Line2D([0], [0], color='k', lw=2, linestyle='--'),
                Line2D([0], [0], color='k', lw=2, linestyle=':')]

ax2.legend(custom_lines, ['Target (File)', 'LTE', 'NLTE (Calc)'], loc='lower left', title='Mode')
ax2.set_title(f"Bifrost Pixel ({col_pix}, {row_pix})")
ax2.set_xlabel("Height [m]")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- Plotting profiles ---
fig, ax = plt.subplots(figsize=(18, 10))

# Plot intensity
ax.plot(wave, I_lte, label='LTE', color='C0', linestyle='--')
ax.plot(wave, I_target, label='Target (from Pops)', color='C1')
ax.plot(wave, I_nlte, label='NLTE (Converged pops)', color='C2', linestyle=':')
ax.plot(wave, I_lw_nlte, label='NLTE (FALC)', color='C3', linestyle='-.')

# Formatting
ax.set_xlabel(r'Wavelength [$\AA$]')
ax.set_ylabel(r'Intensity [erg s$^{-1}$ cm$^{-2}$ Hz$^{-1}$ sr$^{-1}$]')
ax.set_title(f'Ca II 8542 Profile (Pixel: {col_pix}, {row_pix})')
ax.legend()

plt.show()

# %%
# --- Create Plot ---
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# --- Panel 1: Temperature ---
axs[0, 0].plot(z_atm[useful_atm_slice], temp_atm[useful_atm_slice], color='firebrick', linewidth=2, label='Target Pixel')
axs[0, 0].plot(z_falc_m, temp_falc, color='black', linestyle='--', linewidth=2, label='FALC82')
axs[0, 0].set_ylabel('Temperature [K]')
axs[0, 0].set_title('Temperature Stratification')
axs[0, 0].legend()
axs[0, 0].set_yscale('log')
axs[0, 0].grid(True, alpha=0.3)

# --- Panel 2: Magnetic Field (LOS) ---
axs[0, 1].plot(z_atm[useful_atm_slice], b_xyz_atm[useful_atm_slice], color='purple', linewidth=2, label='Target Pixel')
axs[0, 1].axhline(0, color='black', linestyle='--', linewidth=1.5, label='FALC82 (B=0)')
axs[0, 1].set_ylabel('Magnetic Field $B_{LOS}$ [G]')
axs[0, 1].set_title('LOS Magnetic Field')
axs[0, 1].legend()
axs[0, 1].grid(True, alpha=0.3)

# --- Panel 3: Velocity (LOS) ---
axs[1, 0].plot(z_atm[useful_atm_slice], vel_atm[useful_atm_slice], color='teal', linewidth=2, label='Target Pixel')
axs[1, 0].plot(z_falc_m, vlos_falc, color='black', linestyle='--', linewidth=2, label='FALC82')
axs[1, 0].set_ylabel('Velocity [cm/s]')
axs[1, 0].set_xlabel('Height [m]')
axs[1, 0].set_title('LOS Velocity')
axs[1, 0].legend()
axs[1, 0].grid(True, alpha=0.3)

# --- Panel 4: Number Densities ---
# Target
# axs[1, 1].plot(z_atm[useful_atm_slice], n_h_atm[useful_atm_slice], label=r'Target $n_H$', color='firebrick')
axs[1, 1].plot(z_atm[useful_atm_slice], n_e_atm[useful_atm_slice], label=r'Target $n_e$', color='blue', linestyle=':')
# FALC
axs[1, 1].plot(z_falc_m, nh_falc, label=r'FALC $n_H$', color='black', linestyle='--')
axs[1, 1].plot(z_falc_m, ne_falc, label=r'FALC $n_e$', color='black', linestyle=':')

axs[1, 1].set_yscale('log')
axs[1, 1].set_ylabel(r'Number Density [cm$^{-3}$]')
axs[1, 1].set_xlabel('Height [m]')
axs[1, 1].set_title('Particle Densities')
axs[1, 1].legend()
axs[1, 1].grid(True, alpha=0.3, which='both')

plt.suptitle(f'Atmosphere Parameters Comparison (Pixel: {col_pix}, {row_pix})', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()
